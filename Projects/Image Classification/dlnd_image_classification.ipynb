# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [02:36, 1.09MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np 

# Explore the dataset
batch_id = 3
sample_id = 4
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 4:
# Image - Min Value: 10 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 9 Name: truck

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    a = 0
    b = 1
    x_min = np.min(x)
    x_max = np.max(x)
    return a + (x - x_min)*(b-a)/(x_max - x_min)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    x = np.array(x)
    one_hot_encode = np.zeros((x.shape[0], 10))
    one_hot_encode[np.arange(x.shape[0]), x] = 1
    return one_hot_encode

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    batch_size = None
    shape = image_shape
    x = tf.placeholder(
        tf.float32, 
        shape=[batch_size, *shape], 
        name='x'
    )
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    batch_size = None
    n_classes = n_classes
    y = tf.placeholder(
        tf.float32, 
        shape=[batch_size, n_classes], 
        name='y'
    )
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder(
        tf.float32, 
        shape=None, 
        name="keep_prob"
    )
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, 
                   conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    weight = tf.Variable(tf.random_normal(
        [conv_ksize[0], 
         conv_ksize[1],
         x_tensor.get_shape().as_list()[3], 
         conv_num_outputs], 
        stddev=0.1)
    )
    
    bias = tf.Variable(tf.random_normal(
        [conv_num_outputs], 
        stddev=0.1)
    )
    
    conv_layer = tf.nn.conv2d(
            x_tensor, 
            weight, 
            [1, conv_strides[0], conv_strides[1], 1],
            padding='SAME'
    )
    
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    conv_layer = tf.nn.max_pool(
        conv_layer, 
        [1, pool_ksize[0], pool_ksize[1], 1],
        [1, pool_strides[0], pool_strides[1], 1], 
        padding='SAME'
    )
    
    return conv_layer 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
import numpy as np
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(
        x_tensor, 
        num_outputs, 
        tf.nn.relu
    )

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(
        x_tensor, 
        num_outputs
    )

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    # Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    # conv2d_maxpool(x_tensor,conv_num_outputs,conv_ksize,conv_strides,pool_ksize,pool_strides)
    
    # low level concepts from an image
    layer_1 = conv2d_maxpool(
        x, 64, (8,8), (2,2), (2,2), (2,2)
    )
    
    # higher level concepts from layer 1 from an image
    layer_2 = conv2d_maxpool(
        layer_1, 64, (8,8), (2,2), (2,2), (2,2)
    )

    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    flattened_layer = flatten(layer_2)
    flattened_layer = tf.nn.dropout(flattened_layer, keep_prob)
    
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    fc_layer_1 = fully_conn(flattened_layer, 20)
    fc_layer_1 = tf.nn.dropout(fc_layer_1, keep_prob)
    fc_layer_2 = fully_conn(fc_layer_1, 15)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    logits = output(fc_layer_2, 10)
    
    
    # TODO: return output
    
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function       
    session.run(optimizer, feed_dict={
             x: feature_batch, 
             y: label_batch, 
             keep_prob: keep_probability}) 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
        x: feature_batch, 
        y: label_batch, 
        keep_prob: keep_probability})
    
    validation = session.run(accuracy, feed_dict={
        x: valid_features, 
        y: valid_labels, 
        keep_prob: 1.0})
    
    print('    Cost: ', loss, '    Validation accuracy: ', validation)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.7

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2},     CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1,     CIFAR-10 Batch 1:      Cost:  2.30607     Validation accuracy:  0.0978
# Epoch  2,     CIFAR-10 Batch 1:      Cost:  2.2925     Validation accuracy:  0.1222
# Epoch  3,     CIFAR-10 Batch 1:      Cost:  2.26766     Validation accuracy:  0.1726
# Epoch  4,     CIFAR-10 Batch 1:      Cost:  2.26553     Validation accuracy:  0.2036
# Epoch  5,     CIFAR-10 Batch 1:      Cost:  2.24202     Validation accuracy:  0.2052
# Epoch  6,     CIFAR-10 Batch 1:      Cost:  2.21944     Validation accuracy:  0.2216
# Epoch  7,     CIFAR-10 Batch 1:      Cost:  2.18706     Validation accuracy:  0.2394
# Epoch  8,     CIFAR-10 Batch 1:      Cost:  2.15631     Validation accuracy:  0.2626
# Epoch  9,     CIFAR-10 Batch 1:      Cost:  2.11662     Validation accuracy:  0.2956
# Epoch 10,     CIFAR-10 Batch 1:      Cost:  2.03437     Validation accuracy:  0.3192
# Epoch 11,     CIFAR-10 Batch 1:      Cost:  1.98577     Validation accuracy:  0.3402
# Epoch 12,     CIFAR-10 Batch 1:      Cost:  2.00604     Validation accuracy:  0.3446
# Epoch 13,     CIFAR-10 Batch 1:      Cost:  1.95211     Validation accuracy:  0.3444
# Epoch 14,     CIFAR-10 Batch 1:      Cost:  1.84352     Validation accuracy:  0.3678
# Epoch 15,     CIFAR-10 Batch 1:      Cost:  1.85851     Validation accuracy:  0.3642
# Epoch 16,     CIFAR-10 Batch 1:      Cost:  1.82771     Validation accuracy:  0.3464
# Epoch 17,     CIFAR-10 Batch 1:      Cost:  1.78385     Validation accuracy:  0.397
# Epoch 18,     CIFAR-10 Batch 1:      Cost:  1.70316     Validation accuracy:  0.4074
# Epoch 19,     CIFAR-10 Batch 1:      Cost:  1.71637     Validation accuracy:  0.4088
# Epoch 20,     CIFAR-10 Batch 1:      Cost:  1.64766     Validation accuracy:  0.4342
# Epoch 21,     CIFAR-10 Batch 1:      Cost:  1.59671     Validation accuracy:  0.4482
# Epoch 22,     CIFAR-10 Batch 1:      Cost:  1.58302     Validation accuracy:  0.4562
# Epoch 23,     CIFAR-10 Batch 1:      Cost:  1.54616     Validation accuracy:  0.4606
# Epoch 24,     CIFAR-10 Batch 1:      Cost:  1.45321     Validation accuracy:  0.466
# Epoch 25,     CIFAR-10 Batch 1:      Cost:  1.50669     Validation accuracy:  0.4552
# Epoch 26,     CIFAR-10 Batch 1:      Cost:  1.39037     Validation accuracy:  0.4694
# Epoch 27,     CIFAR-10 Batch 1:      Cost:  1.41636     Validation accuracy:  0.4806
# Epoch 28,     CIFAR-10 Batch 1:      Cost:  1.33786     Validation accuracy:  0.4822
# Epoch 29,     CIFAR-10 Batch 1:      Cost:  1.31269     Validation accuracy:  0.4956
# Epoch 30,     CIFAR-10 Batch 1:      Cost:  1.27054     Validation accuracy:  0.504
# Epoch 31,     CIFAR-10 Batch 1:      Cost:  1.25584     Validation accuracy:  0.508
# Epoch 32,     CIFAR-10 Batch 1:      Cost:  1.221     Validation accuracy:  0.4944
# Epoch 33,     CIFAR-10 Batch 1:      Cost:  1.17354     Validation accuracy:  0.4894
# Epoch 34,     CIFAR-10 Batch 1:      Cost:  1.20595     Validation accuracy:  0.5132
# Epoch 35,     CIFAR-10 Batch 1:      Cost:  1.1532     Validation accuracy:  0.5184
# Epoch 36,     CIFAR-10 Batch 1:      Cost:  1.05765     Validation accuracy:  0.52
# Epoch 37,     CIFAR-10 Batch 1:      Cost:  1.11858     Validation accuracy:  0.5164
# Epoch 38,     CIFAR-10 Batch 1:      Cost:  1.14514     Validation accuracy:  0.5136
# Epoch 39,     CIFAR-10 Batch 1:      Cost:  1.06251     Validation accuracy:  0.5198
# Epoch 40,     CIFAR-10 Batch 1:      Cost:  1.07741     Validation accuracy:  0.5262
# Epoch 41,     CIFAR-10 Batch 1:      Cost:  1.02964     Validation accuracy:  0.5234
# Epoch 42,     CIFAR-10 Batch 1:      Cost:  0.95698     Validation accuracy:  0.5226
# Epoch 43,     CIFAR-10 Batch 1:      Cost:  0.901494     Validation accuracy:  0.5286
# Epoch 44,     CIFAR-10 Batch 1:      Cost:  0.9232     Validation accuracy:  0.535
# Epoch 45,     CIFAR-10 Batch 1:      Cost:  0.82132     Validation accuracy:  0.5428
# Epoch 46,     CIFAR-10 Batch 1:      Cost:  0.982469     Validation accuracy:  0.521
# Epoch 47,     CIFAR-10 Batch 1:      Cost:  0.89888     Validation accuracy:  0.5332
# Epoch 48,     CIFAR-10 Batch 1:      Cost:  0.782728     Validation accuracy:  0.5306
# Epoch 49,     CIFAR-10 Batch 1:      Cost:  0.861397     Validation accuracy:  0.5352
# Epoch 50,     CIFAR-10 Batch 1:      Cost:  0.848869     Validation accuracy:  0.5186
# Epoch 51,     CIFAR-10 Batch 1:      Cost:  0.748438     Validation accuracy:  0.5446
# Epoch 52,     CIFAR-10 Batch 1:      Cost:  0.81582     Validation accuracy:  0.5306
# Epoch 53,     CIFAR-10 Batch 1:      Cost:  0.774586     Validation accuracy:  0.5434
# Epoch 54,     CIFAR-10 Batch 1:      Cost:  0.763104     Validation accuracy:  0.545
# Epoch 55,     CIFAR-10 Batch 1:      Cost:  0.7133     Validation accuracy:  0.5438
# Epoch 56,     CIFAR-10 Batch 1:      Cost:  0.692848     Validation accuracy:  0.5422
# Epoch 57,     CIFAR-10 Batch 1:      Cost:  0.711257     Validation accuracy:  0.5538
# Epoch 58,     CIFAR-10 Batch 1:      Cost:  0.655581     Validation accuracy:  0.5444
# Epoch 59,     CIFAR-10 Batch 1:      Cost:  0.671694     Validation accuracy:  0.55
# Epoch 60,     CIFAR-10 Batch 1:      Cost:  0.710571     Validation accuracy:  0.5402
# Epoch 61,     CIFAR-10 Batch 1:      Cost:  0.581277     Validation accuracy:  0.5454
# Epoch 62,     CIFAR-10 Batch 1:      Cost:  0.641595     Validation accuracy:  0.5526
# Epoch 63,     CIFAR-10 Batch 1:      Cost:  0.520583     Validation accuracy:  0.5498
# Epoch 64,     CIFAR-10 Batch 1:      Cost:  0.570594     Validation accuracy:  0.5518
# Epoch 65,     CIFAR-10 Batch 1:      Cost:  0.557579     Validation accuracy:  0.55
# Epoch 66,     CIFAR-10 Batch 1:      Cost:  0.527078     Validation accuracy:  0.55
# Epoch 67,     CIFAR-10 Batch 1:      Cost:  0.494618     Validation accuracy:  0.5526
# Epoch 68,     CIFAR-10 Batch 1:      Cost:  0.523589     Validation accuracy:  0.5518
# Epoch 69,     CIFAR-10 Batch 1:      Cost:  0.51873     Validation accuracy:  0.5482
# Epoch 70,     CIFAR-10 Batch 1:      Cost:  0.588166     Validation accuracy:  0.5462
# Epoch 71,     CIFAR-10 Batch 1:      Cost:  0.481796     Validation accuracy:  0.5332
# Epoch 72,     CIFAR-10 Batch 1:      Cost:  0.553604     Validation accuracy:  0.535
# Epoch 73,     CIFAR-10 Batch 1:      Cost:  0.509525     Validation accuracy:  0.5396
# Epoch 74,     CIFAR-10 Batch 1:      Cost:  0.481559     Validation accuracy:  0.5408
# Epoch 75,     CIFAR-10 Batch 1:      Cost:  0.412903     Validation accuracy:  0.545
# Epoch 76,     CIFAR-10 Batch 1:      Cost:  0.444635     Validation accuracy:  0.541
# Epoch 77,     CIFAR-10 Batch 1:      Cost:  0.470583     Validation accuracy:  0.527
# Epoch 78,     CIFAR-10 Batch 1:      Cost:  0.417768     Validation accuracy:  0.5494
# Epoch 79,     CIFAR-10 Batch 1:      Cost:  0.408145     Validation accuracy:  0.5306
# Epoch 80,     CIFAR-10 Batch 1:      Cost:  0.498689     Validation accuracy:  0.5342
# Epoch 81,     CIFAR-10 Batch 1:      Cost:  0.431725     Validation accuracy:  0.5378
# Epoch 82,     CIFAR-10 Batch 1:      Cost:  0.38004     Validation accuracy:  0.546
# Epoch 83,     CIFAR-10 Batch 1:      Cost:  0.460811     Validation accuracy:  0.5452
# Epoch 84,     CIFAR-10 Batch 1:      Cost:  0.382982     Validation accuracy:  0.5452
# Epoch 85,     CIFAR-10 Batch 1:      Cost:  0.427621     Validation accuracy:  0.5374
# Epoch 86,     CIFAR-10 Batch 1:      Cost:  0.423545     Validation accuracy:  0.5452
# Epoch 87,     CIFAR-10 Batch 1:      Cost:  0.374127     Validation accuracy:  0.5484
# Epoch 88,     CIFAR-10 Batch 1:      Cost:  0.403042     Validation accuracy:  0.5398
# Epoch 89,     CIFAR-10 Batch 1:      Cost:  0.348441     Validation accuracy:  0.5418
# Epoch 90,     CIFAR-10 Batch 1:      Cost:  0.354145     Validation accuracy:  0.5318
# Epoch 91,     CIFAR-10 Batch 1:      Cost:  0.305408     Validation accuracy:  0.5462
# Epoch 92,     CIFAR-10 Batch 1:      Cost:  0.351495     Validation accuracy:  0.5458
# Epoch 93,     CIFAR-10 Batch 1:      Cost:  0.362198     Validation accuracy:  0.5538
# Epoch 94,     CIFAR-10 Batch 1:      Cost:  0.318875     Validation accuracy:  0.5516
# Epoch 95,     CIFAR-10 Batch 1:      Cost:  0.295588     Validation accuracy:  0.5486
# Epoch 96,     CIFAR-10 Batch 1:      Cost:  0.3685     Validation accuracy:  0.5484
# Epoch 97,     CIFAR-10 Batch 1:      Cost:  0.319677     Validation accuracy:  0.543
# Epoch 98,     CIFAR-10 Batch 1:      Cost:  0.3216     Validation accuracy:  0.5434
# Epoch 99,     CIFAR-10 Batch 1:      Cost:  0.359124     Validation accuracy:  0.5514
# Epoch 100,     CIFAR-10 Batch 1:      Cost:  0.275955     Validation accuracy:  0.5452

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:      Cost:  2.31763     Validation accuracy:  0.1204
# Epoch  1, CIFAR-10 Batch 2:      Cost:  2.30425     Validation accuracy:  0.126
# Epoch  1, CIFAR-10 Batch 3:      Cost:  2.29706     Validation accuracy:  0.1384
# Epoch  1, CIFAR-10 Batch 4:      Cost:  2.29727     Validation accuracy:  0.1642
# Epoch  1, CIFAR-10 Batch 5:      Cost:  2.27794     Validation accuracy:  0.1904
# Epoch  2, CIFAR-10 Batch 1:      Cost:  2.27759     Validation accuracy:  0.1984
# Epoch  2, CIFAR-10 Batch 2:      Cost:  2.21981     Validation accuracy:  0.2408
# Epoch  2, CIFAR-10 Batch 3:      Cost:  2.20355     Validation accuracy:  0.2666
# Epoch  2, CIFAR-10 Batch 4:      Cost:  2.09006     Validation accuracy:  0.2842
# Epoch  2, CIFAR-10 Batch 5:      Cost:  2.09903     Validation accuracy:  0.2994
# Epoch  3, CIFAR-10 Batch 1:      Cost:  2.13597     Validation accuracy:  0.3072
# Epoch  3, CIFAR-10 Batch 2:      Cost:  2.03112     Validation accuracy:  0.3256
# Epoch  3, CIFAR-10 Batch 3:      Cost:  1.9711     Validation accuracy:  0.3434
# Epoch  3, CIFAR-10 Batch 4:      Cost:  1.88464     Validation accuracy:  0.3502
# Epoch  3, CIFAR-10 Batch 5:      Cost:  1.94273     Validation accuracy:  0.3736
# Epoch  4, CIFAR-10 Batch 1:      Cost:  1.89982     Validation accuracy:  0.3878
# Epoch  4, CIFAR-10 Batch 2:      Cost:  1.80415     Validation accuracy:  0.4102
# Epoch  4, CIFAR-10 Batch 3:      Cost:  1.80739     Validation accuracy:  0.4188
# Epoch  4, CIFAR-10 Batch 4:      Cost:  1.73283     Validation accuracy:  0.4152
# Epoch  4, CIFAR-10 Batch 5:      Cost:  1.77468     Validation accuracy:  0.4464
# Epoch  5, CIFAR-10 Batch 1:      Cost:  1.77734     Validation accuracy:  0.4454
# Epoch  5, CIFAR-10 Batch 2:      Cost:  1.79858     Validation accuracy:  0.439
# Epoch  5, CIFAR-10 Batch 3:      Cost:  1.6919     Validation accuracy:  0.462
# Epoch  5, CIFAR-10 Batch 4:      Cost:  1.58277     Validation accuracy:  0.4718
# Epoch  5, CIFAR-10 Batch 5:      Cost:  1.62562     Validation accuracy:  0.4786
# Epoch  6, CIFAR-10 Batch 1:      Cost:  1.73663     Validation accuracy:  0.4734
# Epoch  6, CIFAR-10 Batch 2:      Cost:  1.63744     Validation accuracy:  0.4786
# Epoch  6, CIFAR-10 Batch 3:      Cost:  1.51617     Validation accuracy:  0.4906
# Epoch  6, CIFAR-10 Batch 4:      Cost:  1.54328     Validation accuracy:  0.4866
# Epoch  6, CIFAR-10 Batch 5:      Cost:  1.5294     Validation accuracy:  0.5032
# Epoch  7, CIFAR-10 Batch 1:      Cost:  1.52996     Validation accuracy:  0.4904
# Epoch  7, CIFAR-10 Batch 2:      Cost:  1.5235     Validation accuracy:  0.5032
# Epoch  7, CIFAR-10 Batch 3:      Cost:  1.4529     Validation accuracy:  0.5052
# Epoch  7, CIFAR-10 Batch 4:      Cost:  1.37875     Validation accuracy:  0.506
# Epoch  7, CIFAR-10 Batch 5:      Cost:  1.45058     Validation accuracy:  0.5258
# Epoch  8, CIFAR-10 Batch 1:      Cost:  1.39647     Validation accuracy:  0.5158
# Epoch  8, CIFAR-10 Batch 2:      Cost:  1.48902     Validation accuracy:  0.5178
# Epoch  8, CIFAR-10 Batch 3:      Cost:  1.31355     Validation accuracy:  0.5238
# Epoch  8, CIFAR-10 Batch 4:      Cost:  1.3315     Validation accuracy:  0.5254
# Epoch  8, CIFAR-10 Batch 5:      Cost:  1.31358     Validation accuracy:  0.5352
# Epoch  9, CIFAR-10 Batch 1:      Cost:  1.40666     Validation accuracy:  0.5294
# Epoch  9, CIFAR-10 Batch 2:      Cost:  1.37945     Validation accuracy:  0.529
# Epoch  9, CIFAR-10 Batch 3:      Cost:  1.2728     Validation accuracy:  0.5266
# Epoch  9, CIFAR-10 Batch 4:      Cost:  1.26959     Validation accuracy:  0.5334
# Epoch  9, CIFAR-10 Batch 5:      Cost:  1.27626     Validation accuracy:  0.5396
# Epoch 10, CIFAR-10 Batch 1:      Cost:  1.42774     Validation accuracy:  0.544
# Epoch 10, CIFAR-10 Batch 2:      Cost:  1.31874     Validation accuracy:  0.5434
# Epoch 10, CIFAR-10 Batch 3:      Cost:  1.26324     Validation accuracy:  0.5536
# Epoch 10, CIFAR-10 Batch 4:      Cost:  1.18846     Validation accuracy:  0.5528
# Epoch 10, CIFAR-10 Batch 5:      Cost:  1.27233     Validation accuracy:  0.5498
# Epoch 11, CIFAR-10 Batch 1:      Cost:  1.2633     Validation accuracy:  0.549
# Epoch 11, CIFAR-10 Batch 2:      Cost:  1.37943     Validation accuracy:  0.5398
# Epoch 11, CIFAR-10 Batch 3:      Cost:  1.14489     Validation accuracy:  0.5594
# Epoch 11, CIFAR-10 Batch 4:      Cost:  1.12902     Validation accuracy:  0.5574
# Epoch 11, CIFAR-10 Batch 5:      Cost:  1.19678     Validation accuracy:  0.5516
# Epoch 12, CIFAR-10 Batch 1:      Cost:  1.32131     Validation accuracy:  0.556
# Epoch 12, CIFAR-10 Batch 2:      Cost:  1.32919     Validation accuracy:  0.5348
# Epoch 12, CIFAR-10 Batch 3:      Cost:  1.16489     Validation accuracy:  0.5604
# Epoch 12, CIFAR-10 Batch 4:      Cost:  1.08206     Validation accuracy:  0.5636
# Epoch 12, CIFAR-10 Batch 5:      Cost:  1.12743     Validation accuracy:  0.571
# Epoch 13, CIFAR-10 Batch 1:      Cost:  1.255     Validation accuracy:  0.5668
# Epoch 13, CIFAR-10 Batch 2:      Cost:  1.21999     Validation accuracy:  0.5614
# Epoch 13, CIFAR-10 Batch 3:      Cost:  1.0718     Validation accuracy:  0.5742
# Epoch 13, CIFAR-10 Batch 4:      Cost:  1.06146     Validation accuracy:  0.5682
# Epoch 13, CIFAR-10 Batch 5:      Cost:  1.11566     Validation accuracy:  0.5788
# Epoch 14, CIFAR-10 Batch 1:      Cost:  1.19026     Validation accuracy:  0.582
# Epoch 14, CIFAR-10 Batch 2:      Cost:  1.21044     Validation accuracy:  0.5602
# Epoch 14, CIFAR-10 Batch 3:      Cost:  1.13394     Validation accuracy:  0.5758
# Epoch 14, CIFAR-10 Batch 4:      Cost:  1.01629     Validation accuracy:  0.5786
# Epoch 14, CIFAR-10 Batch 5:      Cost:  1.10865     Validation accuracy:  0.5868
# Epoch 15, CIFAR-10 Batch 1:      Cost:  1.15715     Validation accuracy:  0.5846
# Epoch 15, CIFAR-10 Batch 2:      Cost:  1.12731     Validation accuracy:  0.577
# Epoch 15, CIFAR-10 Batch 3:      Cost:  0.994618     Validation accuracy:  0.5786
# Epoch 15, CIFAR-10 Batch 4:      Cost:  1.00597     Validation accuracy:  0.5818
# Epoch 15, CIFAR-10 Batch 5:      Cost:  1.10397     Validation accuracy:  0.5934
# Epoch 16, CIFAR-10 Batch 1:      Cost:  1.15944     Validation accuracy:  0.6026
# Epoch 16, CIFAR-10 Batch 2:      Cost:  1.1076     Validation accuracy:  0.575
# Epoch 16, CIFAR-10 Batch 3:      Cost:  0.99604     Validation accuracy:  0.588
# Epoch 16, CIFAR-10 Batch 4:      Cost:  0.990228     Validation accuracy:  0.5994
# Epoch 16, CIFAR-10 Batch 5:      Cost:  1.03188     Validation accuracy:  0.5918
# Epoch 17, CIFAR-10 Batch 1:      Cost:  1.05617     Validation accuracy:  0.6006
# Epoch 17, CIFAR-10 Batch 2:      Cost:  1.04375     Validation accuracy:  0.5678
# Epoch 17, CIFAR-10 Batch 3:      Cost:  0.978982     Validation accuracy:  0.5972
# Epoch 17, CIFAR-10 Batch 4:      Cost:  0.902276     Validation accuracy:  0.5984
# Epoch 17, CIFAR-10 Batch 5:      Cost:  1.05019     Validation accuracy:  0.5946
# Epoch 18, CIFAR-10 Batch 1:      Cost:  1.07559     Validation accuracy:  0.5844
# Epoch 18, CIFAR-10 Batch 2:      Cost:  1.14345     Validation accuracy:  0.5566
# Epoch 18, CIFAR-10 Batch 3:      Cost:  0.993826     Validation accuracy:  0.5786
# Epoch 18, CIFAR-10 Batch 4:      Cost:  0.976983     Validation accuracy:  0.5972
# Epoch 18, CIFAR-10 Batch 5:      Cost:  1.0378     Validation accuracy:  0.6072
# Epoch 19, CIFAR-10 Batch 1:      Cost:  1.02086     Validation accuracy:  0.5872
# Epoch 19, CIFAR-10 Batch 2:      Cost:  1.05921     Validation accuracy:  0.5864
# Epoch 19, CIFAR-10 Batch 3:      Cost:  1.02441     Validation accuracy:  0.6042
# Epoch 19, CIFAR-10 Batch 4:      Cost:  0.898414     Validation accuracy:  0.6076
# Epoch 19, CIFAR-10 Batch 5:      Cost:  0.934714     Validation accuracy:  0.6058
# Epoch 20, CIFAR-10 Batch 1:      Cost:  1.06755     Validation accuracy:  0.5818
# Epoch 20, CIFAR-10 Batch 2:      Cost:  1.01042     Validation accuracy:  0.6064
# Epoch 20, CIFAR-10 Batch 3:      Cost:  0.961539     Validation accuracy:  0.6038
# Epoch 20, CIFAR-10 Batch 4:      Cost:  0.981896     Validation accuracy:  0.5986
# Epoch 20, CIFAR-10 Batch 5:      Cost:  0.877428     Validation accuracy:  0.6134
# Epoch 21, CIFAR-10 Batch 1:      Cost:  1.05746     Validation accuracy:  0.592
# Epoch 21, CIFAR-10 Batch 2:      Cost:  0.969906     Validation accuracy:  0.6026
# Epoch 21, CIFAR-10 Batch 3:      Cost:  0.91416     Validation accuracy:  0.611
# Epoch 21, CIFAR-10 Batch 4:      Cost:  0.895051     Validation accuracy:  0.6036
# Epoch 21, CIFAR-10 Batch 5:      Cost:  0.886328     Validation accuracy:  0.6064
# Epoch 22, CIFAR-10 Batch 1:      Cost:  0.976302     Validation accuracy:  0.5802
# Epoch 22, CIFAR-10 Batch 2:      Cost:  0.935587     Validation accuracy:  0.6026
# Epoch 22, CIFAR-10 Batch 3:      Cost:  0.873708     Validation accuracy:  0.6102
# Epoch 22, CIFAR-10 Batch 4:      Cost:  0.850257     Validation accuracy:  0.6138
# Epoch 22, CIFAR-10 Batch 5:      Cost:  0.9     Validation accuracy:  0.6174
# Epoch 23, CIFAR-10 Batch 1:      Cost:  0.933973     Validation accuracy:  0.6068
# Epoch 23, CIFAR-10 Batch 2:      Cost:  0.979861     Validation accuracy:  0.61
# Epoch 23, CIFAR-10 Batch 3:      Cost:  0.896666     Validation accuracy:  0.6106
# Epoch 23, CIFAR-10 Batch 4:      Cost:  0.8899     Validation accuracy:  0.6238
# Epoch 23, CIFAR-10 Batch 5:      Cost:  0.865488     Validation accuracy:  0.621
# Epoch 24, CIFAR-10 Batch 1:      Cost:  0.947449     Validation accuracy:  0.602
# Epoch 24, CIFAR-10 Batch 2:      Cost:  0.90204     Validation accuracy:  0.611
# Epoch 24, CIFAR-10 Batch 3:      Cost:  0.870119     Validation accuracy:  0.6248
# Epoch 24, CIFAR-10 Batch 4:      Cost:  0.799984     Validation accuracy:  0.6138
# Epoch 24, CIFAR-10 Batch 5:      Cost:  0.816919     Validation accuracy:  0.6136
# Epoch 25, CIFAR-10 Batch 1:      Cost:  0.902038     Validation accuracy:  0.6094
# Epoch 25, CIFAR-10 Batch 2:      Cost:  0.889581     Validation accuracy:  0.621
# Epoch 25, CIFAR-10 Batch 3:      Cost:  0.841426     Validation accuracy:  0.6178
# Epoch 25, CIFAR-10 Batch 4:      Cost:  0.786233     Validation accuracy:  0.6158
# Epoch 25, CIFAR-10 Batch 5:      Cost:  0.825783     Validation accuracy:  0.6104
# Epoch 26, CIFAR-10 Batch 1:      Cost:  0.88482     Validation accuracy:  0.6074
# Epoch 26, CIFAR-10 Batch 2:      Cost:  0.850173     Validation accuracy:  0.6248
# Epoch 26, CIFAR-10 Batch 3:      Cost:  0.796778     Validation accuracy:  0.6306
# Epoch 26, CIFAR-10 Batch 4:      Cost:  0.8249     Validation accuracy:  0.6212
# Epoch 26, CIFAR-10 Batch 5:      Cost:  0.825381     Validation accuracy:  0.6082
# Epoch 27, CIFAR-10 Batch 1:      Cost:  0.812885     Validation accuracy:  0.6246
# Epoch 27, CIFAR-10 Batch 2:      Cost:  0.878345     Validation accuracy:  0.6296
# Epoch 27, CIFAR-10 Batch 3:      Cost:  0.764041     Validation accuracy:  0.6154
# Epoch 27, CIFAR-10 Batch 4:      Cost:  0.788957     Validation accuracy:  0.611
# Epoch 27, CIFAR-10 Batch 5:      Cost:  0.732152     Validation accuracy:  0.6152
# Epoch 28, CIFAR-10 Batch 1:      Cost:  0.848326     Validation accuracy:  0.6206
# Epoch 28, CIFAR-10 Batch 2:      Cost:  0.815395     Validation accuracy:  0.6268
# Epoch 28, CIFAR-10 Batch 3:      Cost:  0.709676     Validation accuracy:  0.634
# Epoch 28, CIFAR-10 Batch 4:      Cost:  0.746547     Validation accuracy:  0.6192
# Epoch 28, CIFAR-10 Batch 5:      Cost:  0.763445     Validation accuracy:  0.6266
# Epoch 29, CIFAR-10 Batch 1:      Cost:  0.827944     Validation accuracy:  0.6214
# Epoch 29, CIFAR-10 Batch 2:      Cost:  0.762793     Validation accuracy:  0.6336
# Epoch 29, CIFAR-10 Batch 3:      Cost:  0.708197     Validation accuracy:  0.6248
# Epoch 29, CIFAR-10 Batch 4:      Cost:  0.763167     Validation accuracy:  0.6312
# Epoch 29, CIFAR-10 Batch 5:      Cost:  0.744006     Validation accuracy:  0.6372
# Epoch 30, CIFAR-10 Batch 1:      Cost:  0.732867     Validation accuracy:  0.629
# Epoch 30, CIFAR-10 Batch 2:      Cost:  0.779282     Validation accuracy:  0.6378
# Epoch 30, CIFAR-10 Batch 3:      Cost:  0.684881     Validation accuracy:  0.631
# Epoch 30, CIFAR-10 Batch 4:      Cost:  0.722606     Validation accuracy:  0.6208
# Epoch 30, CIFAR-10 Batch 5:      Cost:  0.695019     Validation accuracy:  0.6354
# Epoch 31, CIFAR-10 Batch 1:      Cost:  0.769342     Validation accuracy:  0.6244
# Epoch 31, CIFAR-10 Batch 2:      Cost:  0.712065     Validation accuracy:  0.6274
# Epoch 31, CIFAR-10 Batch 3:      Cost:  0.701036     Validation accuracy:  0.6198
# Epoch 31, CIFAR-10 Batch 4:      Cost:  0.73834     Validation accuracy:  0.6318
# Epoch 31, CIFAR-10 Batch 5:      Cost:  0.680261     Validation accuracy:  0.6416
# Epoch 32, CIFAR-10 Batch 1:      Cost:  0.747752     Validation accuracy:  0.627
# Epoch 32, CIFAR-10 Batch 2:      Cost:  0.779905     Validation accuracy:  0.6334
# Epoch 32, CIFAR-10 Batch 3:      Cost:  0.712068     Validation accuracy:  0.6238
# Epoch 32, CIFAR-10 Batch 4:      Cost:  0.725548     Validation accuracy:  0.6212
# Epoch 32, CIFAR-10 Batch 5:      Cost:  0.773038     Validation accuracy:  0.6274
# Epoch 33, CIFAR-10 Batch 1:      Cost:  0.798835     Validation accuracy:  0.6272
# Epoch 33, CIFAR-10 Batch 2:      Cost:  0.765071     Validation accuracy:  0.6336
# Epoch 33, CIFAR-10 Batch 3:      Cost:  0.630823     Validation accuracy:  0.6368
# Epoch 33, CIFAR-10 Batch 4:      Cost:  0.635987     Validation accuracy:  0.6226
# Epoch 33, CIFAR-10 Batch 5:      Cost:  0.653429     Validation accuracy:  0.6264
# Epoch 34, CIFAR-10 Batch 1:      Cost:  0.711536     Validation accuracy:  0.6214
# Epoch 34, CIFAR-10 Batch 2:      Cost:  0.74136     Validation accuracy:  0.6368
# Epoch 34, CIFAR-10 Batch 3:      Cost:  0.664246     Validation accuracy:  0.6352
# Epoch 34, CIFAR-10 Batch 4:      Cost:  0.636649     Validation accuracy:  0.6316
# Epoch 34, CIFAR-10 Batch 5:      Cost:  0.725532     Validation accuracy:  0.6372
# Epoch 35, CIFAR-10 Batch 1:      Cost:  0.762432     Validation accuracy:  0.6308
# Epoch 35, CIFAR-10 Batch 2:      Cost:  0.729898     Validation accuracy:  0.6346
# Epoch 35, CIFAR-10 Batch 3:      Cost:  0.630253     Validation accuracy:  0.6328
# Epoch 35, CIFAR-10 Batch 4:      Cost:  0.645999     Validation accuracy:  0.6326
# Epoch 35, CIFAR-10 Batch 5:      Cost:  0.63527     Validation accuracy:  0.635
# Epoch 36, CIFAR-10 Batch 1:      Cost:  0.736104     Validation accuracy:  0.6274
# Epoch 36, CIFAR-10 Batch 2:      Cost:  0.742235     Validation accuracy:  0.6308
# Epoch 36, CIFAR-10 Batch 3:      Cost:  0.706565     Validation accuracy:  0.629
# Epoch 36, CIFAR-10 Batch 4:      Cost:  0.661369     Validation accuracy:  0.6324
# Epoch 36, CIFAR-10 Batch 5:      Cost:  0.605589     Validation accuracy:  0.6328
# Epoch 37, CIFAR-10 Batch 1:      Cost:  0.700916     Validation accuracy:  0.6238
# Epoch 37, CIFAR-10 Batch 2:      Cost:  0.734535     Validation accuracy:  0.64
# Epoch 37, CIFAR-10 Batch 3:      Cost:  0.59283     Validation accuracy:  0.6414
# Epoch 37, CIFAR-10 Batch 4:      Cost:  0.650878     Validation accuracy:  0.6258
# Epoch 37, CIFAR-10 Batch 5:      Cost:  0.632359     Validation accuracy:  0.6274
# Epoch 38, CIFAR-10 Batch 1:      Cost:  0.685222     Validation accuracy:  0.6294
# Epoch 38, CIFAR-10 Batch 2:      Cost:  0.707438     Validation accuracy:  0.6402
# Epoch 38, CIFAR-10 Batch 3:      Cost:  0.598147     Validation accuracy:  0.6392
# Epoch 38, CIFAR-10 Batch 4:      Cost:  0.676961     Validation accuracy:  0.6344
# Epoch 38, CIFAR-10 Batch 5:      Cost:  0.677269     Validation accuracy:  0.6332
# Epoch 39, CIFAR-10 Batch 1:      Cost:  0.724808     Validation accuracy:  0.6154
# Epoch 39, CIFAR-10 Batch 2:      Cost:  0.681867     Validation accuracy:  0.6454
# Epoch 39, CIFAR-10 Batch 3:      Cost:  0.604411     Validation accuracy:  0.6474
# Epoch 39, CIFAR-10 Batch 4:      Cost:  0.606009     Validation accuracy:  0.6328
# Epoch 39, CIFAR-10 Batch 5:      Cost:  0.579043     Validation accuracy:  0.6376
# Epoch 40, CIFAR-10 Batch 1:      Cost:  0.593812     Validation accuracy:  0.6306
# Epoch 40, CIFAR-10 Batch 2:      Cost:  0.694075     Validation accuracy:  0.6292
# Epoch 40, CIFAR-10 Batch 3:      Cost:  0.534239     Validation accuracy:  0.6352
# Epoch 40, CIFAR-10 Batch 4:      Cost:  0.579276     Validation accuracy:  0.6326
# Epoch 40, CIFAR-10 Batch 5:      Cost:  0.587624     Validation accuracy:  0.6414
# Epoch 41, CIFAR-10 Batch 1:      Cost:  0.588063     Validation accuracy:  0.6298
# Epoch 41, CIFAR-10 Batch 2:      Cost:  0.603334     Validation accuracy:  0.6312
# Epoch 41, CIFAR-10 Batch 3:      Cost:  0.585064     Validation accuracy:  0.6436
# Epoch 41, CIFAR-10 Batch 4:      Cost:  0.554394     Validation accuracy:  0.6288
# Epoch 41, CIFAR-10 Batch 5:      Cost:  0.642573     Validation accuracy:  0.6246
# Epoch 42, CIFAR-10 Batch 1:      Cost:  0.623103     Validation accuracy:  0.631
# Epoch 42, CIFAR-10 Batch 2:      Cost:  0.654271     Validation accuracy:  0.6356
# Epoch 42, CIFAR-10 Batch 3:      Cost:  0.532755     Validation accuracy:  0.644
# Epoch 42, CIFAR-10 Batch 4:      Cost:  0.592843     Validation accuracy:  0.6396
# Epoch 42, CIFAR-10 Batch 5:      Cost:  0.562377     Validation accuracy:  0.6388
# Epoch 43, CIFAR-10 Batch 1:      Cost:  0.703083     Validation accuracy:  0.639
# Epoch 43, CIFAR-10 Batch 2:      Cost:  0.568233     Validation accuracy:  0.6392
# Epoch 43, CIFAR-10 Batch 3:      Cost:  0.604386     Validation accuracy:  0.6388
# Epoch 43, CIFAR-10 Batch 4:      Cost:  0.564967     Validation accuracy:  0.635
# Epoch 43, CIFAR-10 Batch 5:      Cost:  0.588066     Validation accuracy:  0.621
# Epoch 44, CIFAR-10 Batch 1:      Cost:  0.597813     Validation accuracy:  0.6428
# Epoch 44, CIFAR-10 Batch 2:      Cost:  0.577631     Validation accuracy:  0.631
# Epoch 44, CIFAR-10 Batch 3:      Cost:  0.510405     Validation accuracy:  0.6384
# Epoch 44, CIFAR-10 Batch 4:      Cost:  0.553895     Validation accuracy:  0.6348
# Epoch 44, CIFAR-10 Batch 5:      Cost:  0.562177     Validation accuracy:  0.6312
# Epoch 45, CIFAR-10 Batch 1:      Cost:  0.630016     Validation accuracy:  0.6364
# Epoch 45, CIFAR-10 Batch 2:      Cost:  0.583215     Validation accuracy:  0.638
# Epoch 45, CIFAR-10 Batch 3:      Cost:  0.499647     Validation accuracy:  0.6394
# Epoch 45, CIFAR-10 Batch 4:      Cost:  0.55328     Validation accuracy:  0.63
# Epoch 45, CIFAR-10 Batch 5:      Cost:  0.532941     Validation accuracy:  0.6266
# Epoch 46, CIFAR-10 Batch 1:      Cost:  0.565962     Validation accuracy:  0.6378
# Epoch 46, CIFAR-10 Batch 2:      Cost:  0.579102     Validation accuracy:  0.6354
# Epoch 46, CIFAR-10 Batch 3:      Cost:  0.519862     Validation accuracy:  0.636
# Epoch 46, CIFAR-10 Batch 4:      Cost:  0.509643     Validation accuracy:  0.6336
# Epoch 46, CIFAR-10 Batch 5:      Cost:  0.574504     Validation accuracy:  0.6336
# Epoch 47, CIFAR-10 Batch 1:      Cost:  0.610837     Validation accuracy:  0.6342
# Epoch 47, CIFAR-10 Batch 2:      Cost:  0.555371     Validation accuracy:  0.6308
# Epoch 47, CIFAR-10 Batch 3:      Cost:  0.525099     Validation accuracy:  0.6452
# Epoch 47, CIFAR-10 Batch 4:      Cost:  0.549848     Validation accuracy:  0.6312
# Epoch 47, CIFAR-10 Batch 5:      Cost:  0.494701     Validation accuracy:  0.6406
# Epoch 48, CIFAR-10 Batch 1:      Cost:  0.615659     Validation accuracy:  0.6336
# Epoch 48, CIFAR-10 Batch 2:      Cost:  0.578252     Validation accuracy:  0.6476
# Epoch 48, CIFAR-10 Batch 3:      Cost:  0.501489     Validation accuracy:  0.6426
# Epoch 48, CIFAR-10 Batch 4:      Cost:  0.542619     Validation accuracy:  0.635
# Epoch 48, CIFAR-10 Batch 5:      Cost:  0.529765     Validation accuracy:  0.6416
# Epoch 49, CIFAR-10 Batch 1:      Cost:  0.589854     Validation accuracy:  0.6444
# Epoch 49, CIFAR-10 Batch 2:      Cost:  0.554843     Validation accuracy:  0.6476
# Epoch 49, CIFAR-10 Batch 3:      Cost:  0.498553     Validation accuracy:  0.6418
# Epoch 49, CIFAR-10 Batch 4:      Cost:  0.558299     Validation accuracy:  0.6296
# Epoch 49, CIFAR-10 Batch 5:      Cost:  0.58     Validation accuracy:  0.6228
# Epoch 50, CIFAR-10 Batch 1:      Cost:  0.629747     Validation accuracy:  0.6398
# Epoch 50, CIFAR-10 Batch 2:      Cost:  0.585777     Validation accuracy:  0.6404
# Epoch 50, CIFAR-10 Batch 3:      Cost:  0.480851     Validation accuracy:  0.6398
# Epoch 50, CIFAR-10 Batch 4:      Cost:  0.507454     Validation accuracy:  0.6408
# Epoch 50, CIFAR-10 Batch 5:      Cost:  0.471595     Validation accuracy:  0.6384
# Epoch 51, CIFAR-10 Batch 1:      Cost:  0.575104     Validation accuracy:  0.6352
# Epoch 51, CIFAR-10 Batch 2:      Cost:  0.528745     Validation accuracy:  0.6298
# Epoch 51, CIFAR-10 Batch 3:      Cost:  0.452283     Validation accuracy:  0.6442
# Epoch 51, CIFAR-10 Batch 4:      Cost:  0.542358     Validation accuracy:  0.643
# Epoch 51, CIFAR-10 Batch 5:      Cost:  0.553329     Validation accuracy:  0.6408
# Epoch 52, CIFAR-10 Batch 1:      Cost:  0.559612     Validation accuracy:  0.6356
# Epoch 52, CIFAR-10 Batch 2:      Cost:  0.544253     Validation accuracy:  0.6402
# Epoch 52, CIFAR-10 Batch 3:      Cost:  0.515776     Validation accuracy:  0.6316
# Epoch 52, CIFAR-10 Batch 4:      Cost:  0.46934     Validation accuracy:  0.6312
# Epoch 52, CIFAR-10 Batch 5:      Cost:  0.468951     Validation accuracy:  0.6344
# Epoch 53, CIFAR-10 Batch 1:      Cost:  0.582276     Validation accuracy:  0.639
# Epoch 53, CIFAR-10 Batch 2:      Cost:  0.503914     Validation accuracy:  0.6332
# Epoch 53, CIFAR-10 Batch 3:      Cost:  0.424386     Validation accuracy:  0.6376
# Epoch 53, CIFAR-10 Batch 4:      Cost:  0.448491     Validation accuracy:  0.6326
# Epoch 53, CIFAR-10 Batch 5:      Cost:  0.447244     Validation accuracy:  0.6398
# Epoch 54, CIFAR-10 Batch 1:      Cost:  0.593408     Validation accuracy:  0.6394
# Epoch 54, CIFAR-10 Batch 2:      Cost:  0.54285     Validation accuracy:  0.6384
# Epoch 54, CIFAR-10 Batch 3:      Cost:  0.420336     Validation accuracy:  0.639
# Epoch 54, CIFAR-10 Batch 4:      Cost:  0.503686     Validation accuracy:  0.6384
# Epoch 54, CIFAR-10 Batch 5:      Cost:  0.485393     Validation accuracy:  0.6402
# Epoch 55, CIFAR-10 Batch 1:      Cost:  0.527159     Validation accuracy:  0.646
# Epoch 55, CIFAR-10 Batch 2:      Cost:  0.515844     Validation accuracy:  0.6206
# Epoch 55, CIFAR-10 Batch 3:      Cost:  0.449731     Validation accuracy:  0.637
# Epoch 55, CIFAR-10 Batch 4:      Cost:  0.420797     Validation accuracy:  0.64
# Epoch 55, CIFAR-10 Batch 5:      Cost:  0.472052     Validation accuracy:  0.6374
# Epoch 56, CIFAR-10 Batch 1:      Cost:  0.43675     Validation accuracy:  0.6388
# Epoch 56, CIFAR-10 Batch 2:      Cost:  0.51472     Validation accuracy:  0.6326
# Epoch 56, CIFAR-10 Batch 3:      Cost:  0.397249     Validation accuracy:  0.6416
# Epoch 56, CIFAR-10 Batch 4:      Cost:  0.431934     Validation accuracy:  0.6392
# Epoch 56, CIFAR-10 Batch 5:      Cost:  0.428212     Validation accuracy:  0.6358
# Epoch 57, CIFAR-10 Batch 1:      Cost:  0.533675     Validation accuracy:  0.6366
# Epoch 57, CIFAR-10 Batch 2:      Cost:  0.485177     Validation accuracy:  0.627
# Epoch 57, CIFAR-10 Batch 3:      Cost:  0.418964     Validation accuracy:  0.6392
# Epoch 57, CIFAR-10 Batch 4:      Cost:  0.421052     Validation accuracy:  0.6382
# Epoch 57, CIFAR-10 Batch 5:      Cost:  0.454707     Validation accuracy:  0.6274
# Epoch 58, CIFAR-10 Batch 1:      Cost:  0.552364     Validation accuracy:  0.6396
# Epoch 58, CIFAR-10 Batch 2:      Cost:  0.528528     Validation accuracy:  0.6272
# Epoch 58, CIFAR-10 Batch 3:      Cost:  0.438595     Validation accuracy:  0.6302
# Epoch 58, CIFAR-10 Batch 4:      Cost:  0.493709     Validation accuracy:  0.6378
# Epoch 58, CIFAR-10 Batch 5:      Cost:  0.407241     Validation accuracy:  0.6334
# Epoch 59, CIFAR-10 Batch 1:      Cost:  0.509564     Validation accuracy:  0.6442
# Epoch 59, CIFAR-10 Batch 2:      Cost:  0.521471     Validation accuracy:  0.6226
# Epoch 59, CIFAR-10 Batch 3:      Cost:  0.500454     Validation accuracy:  0.646
# Epoch 59, CIFAR-10 Batch 4:      Cost:  0.401643     Validation accuracy:  0.6372
# Epoch 59, CIFAR-10 Batch 5:      Cost:  0.417752     Validation accuracy:  0.6294
# Epoch 60, CIFAR-10 Batch 1:      Cost:  0.495862     Validation accuracy:  0.6428
# Epoch 60, CIFAR-10 Batch 2:      Cost:  0.484893     Validation accuracy:  0.6212
# Epoch 60, CIFAR-10 Batch 3:      Cost:  0.471384     Validation accuracy:  0.6416
# Epoch 60, CIFAR-10 Batch 4:      Cost:  0.435751     Validation accuracy:  0.6314
# Epoch 60, CIFAR-10 Batch 5:      Cost:  0.429477     Validation accuracy:  0.6328
# Epoch 61, CIFAR-10 Batch 1:      Cost:  0.469204     Validation accuracy:  0.642
# Epoch 61, CIFAR-10 Batch 2:      Cost:  0.469252     Validation accuracy:  0.6372
# Epoch 61, CIFAR-10 Batch 3:      Cost:  0.421336     Validation accuracy:  0.6408
# Epoch 61, CIFAR-10 Batch 4:      Cost:  0.4012     Validation accuracy:  0.6296
# Epoch 61, CIFAR-10 Batch 5:      Cost:  0.380175     Validation accuracy:  0.6398
# Epoch 62, CIFAR-10 Batch 1:      Cost:  0.519994     Validation accuracy:  0.6412
# Epoch 62, CIFAR-10 Batch 2:      Cost:  0.506695     Validation accuracy:  0.6254
# Epoch 62, CIFAR-10 Batch 3:      Cost:  0.434065     Validation accuracy:  0.6356
# Epoch 62, CIFAR-10 Batch 4:      Cost:  0.404355     Validation accuracy:  0.637
# Epoch 62, CIFAR-10 Batch 5:      Cost:  0.423056     Validation accuracy:  0.641
# Epoch 63, CIFAR-10 Batch 1:      Cost:  0.492903     Validation accuracy:  0.6392
# Epoch 63, CIFAR-10 Batch 2:      Cost:  0.41701     Validation accuracy:  0.6368
# Epoch 63, CIFAR-10 Batch 3:      Cost:  0.413892     Validation accuracy:  0.632
# Epoch 63, CIFAR-10 Batch 4:      Cost:  0.427877     Validation accuracy:  0.6362
# Epoch 63, CIFAR-10 Batch 5:      Cost:  0.379146     Validation accuracy:  0.64
# Epoch 64, CIFAR-10 Batch 1:      Cost:  0.429801     Validation accuracy:  0.6416
# Epoch 64, CIFAR-10 Batch 2:      Cost:  0.462856     Validation accuracy:  0.6306
# Epoch 64, CIFAR-10 Batch 3:      Cost:  0.425363     Validation accuracy:  0.6414
# Epoch 64, CIFAR-10 Batch 4:      Cost:  0.369339     Validation accuracy:  0.6342
# Epoch 64, CIFAR-10 Batch 5:      Cost:  0.38383     Validation accuracy:  0.6402
# Epoch 65, CIFAR-10 Batch 1:      Cost:  0.487938     Validation accuracy:  0.6414
# Epoch 65, CIFAR-10 Batch 2:      Cost:  0.464859     Validation accuracy:  0.6064
# Epoch 65, CIFAR-10 Batch 3:      Cost:  0.421783     Validation accuracy:  0.6318
# Epoch 65, CIFAR-10 Batch 4:      Cost:  0.507384     Validation accuracy:  0.6154
# Epoch 65, CIFAR-10 Batch 5:      Cost:  0.429821     Validation accuracy:  0.645
# Epoch 66, CIFAR-10 Batch 1:      Cost:  0.426959     Validation accuracy:  0.6348
# Epoch 66, CIFAR-10 Batch 2:      Cost:  0.427627     Validation accuracy:  0.6206
# Epoch 66, CIFAR-10 Batch 3:      Cost:  0.41754     Validation accuracy:  0.6452
# Epoch 66, CIFAR-10 Batch 4:      Cost:  0.40998     Validation accuracy:  0.633
# Epoch 66, CIFAR-10 Batch 5:      Cost:  0.367069     Validation accuracy:  0.6438
# Epoch 67, CIFAR-10 Batch 1:      Cost:  0.525389     Validation accuracy:  0.6364
# Epoch 67, CIFAR-10 Batch 2:      Cost:  0.490464     Validation accuracy:  0.636
# Epoch 67, CIFAR-10 Batch 3:      Cost:  0.376025     Validation accuracy:  0.6402
# Epoch 67, CIFAR-10 Batch 4:      Cost:  0.450769     Validation accuracy:  0.633
# Epoch 67, CIFAR-10 Batch 5:      Cost:  0.444359     Validation accuracy:  0.6462
# Epoch 68, CIFAR-10 Batch 1:      Cost:  0.437011     Validation accuracy:  0.6412
# Epoch 68, CIFAR-10 Batch 2:      Cost:  0.477164     Validation accuracy:  0.633
# Epoch 68, CIFAR-10 Batch 3:      Cost:  0.401246     Validation accuracy:  0.6364
# Epoch 68, CIFAR-10 Batch 4:      Cost:  0.391355     Validation accuracy:  0.6314
# Epoch 68, CIFAR-10 Batch 5:      Cost:  0.338865     Validation accuracy:  0.6368
# Epoch 69, CIFAR-10 Batch 1:      Cost:  0.497743     Validation accuracy:  0.6368
# Epoch 69, CIFAR-10 Batch 2:      Cost:  0.408741     Validation accuracy:  0.6424
# Epoch 69, CIFAR-10 Batch 3:      Cost:  0.39549     Validation accuracy:  0.6332
# Epoch 69, CIFAR-10 Batch 4:      Cost:  0.419374     Validation accuracy:  0.6252
# Epoch 69, CIFAR-10 Batch 5:      Cost:  0.468895     Validation accuracy:  0.6362
# Epoch 70, CIFAR-10 Batch 1:      Cost:  0.426409     Validation accuracy:  0.636
# Epoch 70, CIFAR-10 Batch 2:      Cost:  0.446371     Validation accuracy:  0.6416
# Epoch 70, CIFAR-10 Batch 3:      Cost:  0.413239     Validation accuracy:  0.6366
# Epoch 70, CIFAR-10 Batch 4:      Cost:  0.402886     Validation accuracy:  0.6362
# Epoch 70, CIFAR-10 Batch 5:      Cost:  0.376068     Validation accuracy:  0.6454
# Epoch 71, CIFAR-10 Batch 1:      Cost:  0.41573     Validation accuracy:  0.6424
# Epoch 71, CIFAR-10 Batch 2:      Cost:  0.428043     Validation accuracy:  0.6414
# Epoch 71, CIFAR-10 Batch 3:      Cost:  0.38806     Validation accuracy:  0.6412
# Epoch 71, CIFAR-10 Batch 4:      Cost:  0.357293     Validation accuracy:  0.629
# Epoch 71, CIFAR-10 Batch 5:      Cost:  0.384476     Validation accuracy:  0.6346
# Epoch 72, CIFAR-10 Batch 1:      Cost:  0.402515     Validation accuracy:  0.6476
# Epoch 72, CIFAR-10 Batch 2:      Cost:  0.403389     Validation accuracy:  0.6444
# Epoch 72, CIFAR-10 Batch 3:      Cost:  0.361769     Validation accuracy:  0.639
# Epoch 72, CIFAR-10 Batch 4:      Cost:  0.407516     Validation accuracy:  0.631
# Epoch 72, CIFAR-10 Batch 5:      Cost:  0.319506     Validation accuracy:  0.6436
# Epoch 73, CIFAR-10 Batch 1:      Cost:  0.444828     Validation accuracy:  0.6358
# Epoch 73, CIFAR-10 Batch 2:      Cost:  0.394307     Validation accuracy:  0.6484
# Epoch 73, CIFAR-10 Batch 3:      Cost:  0.39479     Validation accuracy:  0.636
# Epoch 73, CIFAR-10 Batch 4:      Cost:  0.373331     Validation accuracy:  0.618
# Epoch 73, CIFAR-10 Batch 5:      Cost:  0.301965     Validation accuracy:  0.6416
# Epoch 74, CIFAR-10 Batch 1:      Cost:  0.424803     Validation accuracy:  0.6364
# Epoch 74, CIFAR-10 Batch 2:      Cost:  0.475367     Validation accuracy:  0.6392
# Epoch 74, CIFAR-10 Batch 3:      Cost:  0.361737     Validation accuracy:  0.6428
# Epoch 74, CIFAR-10 Batch 4:      Cost:  0.361761     Validation accuracy:  0.6278
# Epoch 74, CIFAR-10 Batch 5:      Cost:  0.321721     Validation accuracy:  0.6308
# Epoch 75, CIFAR-10 Batch 1:      Cost:  0.377923     Validation accuracy:  0.6382
# Epoch 75, CIFAR-10 Batch 2:      Cost:  0.341763     Validation accuracy:  0.6402
# Epoch 75, CIFAR-10 Batch 3:      Cost:  0.335238     Validation accuracy:  0.6298
# Epoch 75, CIFAR-10 Batch 4:      Cost:  0.332943     Validation accuracy:  0.6314
# Epoch 75, CIFAR-10 Batch 5:      Cost:  0.34072     Validation accuracy:  0.6408
# Epoch 76, CIFAR-10 Batch 1:      Cost:  0.406328     Validation accuracy:  0.6402
# Epoch 76, CIFAR-10 Batch 2:      Cost:  0.368334     Validation accuracy:  0.6448
# Epoch 76, CIFAR-10 Batch 3:      Cost:  0.382509     Validation accuracy:  0.6382
# Epoch 76, CIFAR-10 Batch 4:      Cost:  0.356488     Validation accuracy:  0.6402
# Epoch 76, CIFAR-10 Batch 5:      Cost:  0.334146     Validation accuracy:  0.6434
# Epoch 77, CIFAR-10 Batch 1:      Cost:  0.376079     Validation accuracy:  0.6364
# Epoch 77, CIFAR-10 Batch 2:      Cost:  0.373427     Validation accuracy:  0.64
# Epoch 77, CIFAR-10 Batch 3:      Cost:  0.354628     Validation accuracy:  0.6412
# Epoch 77, CIFAR-10 Batch 4:      Cost:  0.332849     Validation accuracy:  0.6386
# Epoch 77, CIFAR-10 Batch 5:      Cost:  0.315798     Validation accuracy:  0.6384
# Epoch 78, CIFAR-10 Batch 1:      Cost:  0.372494     Validation accuracy:  0.642
# Epoch 78, CIFAR-10 Batch 2:      Cost:  0.365457     Validation accuracy:  0.6404
# Epoch 78, CIFAR-10 Batch 3:      Cost:  0.364361     Validation accuracy:  0.635
# Epoch 78, CIFAR-10 Batch 4:      Cost:  0.389813     Validation accuracy:  0.6246
# Epoch 78, CIFAR-10 Batch 5:      Cost:  0.264645     Validation accuracy:  0.6314
# Epoch 79, CIFAR-10 Batch 1:      Cost:  0.450481     Validation accuracy:  0.6364
# Epoch 79, CIFAR-10 Batch 2:      Cost:  0.422242     Validation accuracy:  0.6428
# Epoch 79, CIFAR-10 Batch 3:      Cost:  0.409092     Validation accuracy:  0.6316
# Epoch 79, CIFAR-10 Batch 4:      Cost:  0.364676     Validation accuracy:  0.625
# Epoch 79, CIFAR-10 Batch 5:      Cost:  0.309604     Validation accuracy:  0.6366
# Epoch 80, CIFAR-10 Batch 1:      Cost:  0.419463     Validation accuracy:  0.6358
# Epoch 80, CIFAR-10 Batch 2:      Cost:  0.402147     Validation accuracy:  0.6436
# Epoch 80, CIFAR-10 Batch 3:      Cost:  0.366251     Validation accuracy:  0.6392
# Epoch 80, CIFAR-10 Batch 4:      Cost:  0.342919     Validation accuracy:  0.619
# Epoch 80, CIFAR-10 Batch 5:      Cost:  0.35342     Validation accuracy:  0.6366
# Epoch 81, CIFAR-10 Batch 1:      Cost:  0.411014     Validation accuracy:  0.6314
# Epoch 81, CIFAR-10 Batch 2:      Cost:  0.337254     Validation accuracy:  0.6392
# Epoch 81, CIFAR-10 Batch 3:      Cost:  0.276092     Validation accuracy:  0.6294
# Epoch 81, CIFAR-10 Batch 4:      Cost:  0.321896     Validation accuracy:  0.6394
# Epoch 81, CIFAR-10 Batch 5:      Cost:  0.368106     Validation accuracy:  0.6438
# Epoch 82, CIFAR-10 Batch 1:      Cost:  0.335006     Validation accuracy:  0.6416
# Epoch 82, CIFAR-10 Batch 2:      Cost:  0.346308     Validation accuracy:  0.6442
# Epoch 82, CIFAR-10 Batch 3:      Cost:  0.309362     Validation accuracy:  0.6408
# Epoch 82, CIFAR-10 Batch 4:      Cost:  0.332121     Validation accuracy:  0.6334
# Epoch 82, CIFAR-10 Batch 5:      Cost:  0.274105     Validation accuracy:  0.6376
# Epoch 83, CIFAR-10 Batch 1:      Cost:  0.415006     Validation accuracy:  0.6332
# Epoch 83, CIFAR-10 Batch 2:      Cost:  0.372911     Validation accuracy:  0.6434
# Epoch 83, CIFAR-10 Batch 3:      Cost:  0.283082     Validation accuracy:  0.6404
# Epoch 83, CIFAR-10 Batch 4:      Cost:  0.256261     Validation accuracy:  0.6406
# Epoch 83, CIFAR-10 Batch 5:      Cost:  0.340814     Validation accuracy:  0.6296
# Epoch 84, CIFAR-10 Batch 1:      Cost:  0.414563     Validation accuracy:  0.6406
# Epoch 84, CIFAR-10 Batch 2:      Cost:  0.376629     Validation accuracy:  0.6346
# Epoch 84, CIFAR-10 Batch 3:      Cost:  0.350211     Validation accuracy:  0.642
# Epoch 84, CIFAR-10 Batch 4:      Cost:  0.301686     Validation accuracy:  0.6336
# Epoch 84, CIFAR-10 Batch 5:      Cost:  0.331579     Validation accuracy:  0.6338
# Epoch 85, CIFAR-10 Batch 1:      Cost:  0.339222     Validation accuracy:  0.6354
# Epoch 85, CIFAR-10 Batch 2:      Cost:  0.315376     Validation accuracy:  0.6336
# Epoch 85, CIFAR-10 Batch 3:      Cost:  0.258155     Validation accuracy:  0.6362
# Epoch 85, CIFAR-10 Batch 4:      Cost:  0.340839     Validation accuracy:  0.6346
# Epoch 85, CIFAR-10 Batch 5:      Cost:  0.288342     Validation accuracy:  0.6368
# Epoch 86, CIFAR-10 Batch 1:      Cost:  0.352438     Validation accuracy:  0.643
# Epoch 86, CIFAR-10 Batch 2:      Cost:  0.37442     Validation accuracy:  0.6416
# Epoch 86, CIFAR-10 Batch 3:      Cost:  0.319388     Validation accuracy:  0.638
# Epoch 86, CIFAR-10 Batch 4:      Cost:  0.318434     Validation accuracy:  0.639
# Epoch 86, CIFAR-10 Batch 5:      Cost:  0.235085     Validation accuracy:  0.6388
# Epoch 87, CIFAR-10 Batch 1:      Cost:  0.419349     Validation accuracy:  0.6352
# Epoch 87, CIFAR-10 Batch 2:      Cost:  0.335608     Validation accuracy:  0.6326
# Epoch 87, CIFAR-10 Batch 3:      Cost:  0.25062     Validation accuracy:  0.6378
# Epoch 87, CIFAR-10 Batch 4:      Cost:  0.279322     Validation accuracy:  0.6392
# Epoch 87, CIFAR-10 Batch 5:      Cost:  0.271671     Validation accuracy:  0.6398
# Epoch 88, CIFAR-10 Batch 1:      Cost:  0.356156     Validation accuracy:  0.639
# Epoch 88, CIFAR-10 Batch 2:      Cost:  0.336924     Validation accuracy:  0.6398
# Epoch 88, CIFAR-10 Batch 3:      Cost:  0.275055     Validation accuracy:  0.6426
# Epoch 88, CIFAR-10 Batch 4:      Cost:  0.365793     Validation accuracy:  0.6354
# Epoch 88, CIFAR-10 Batch 5:      Cost:  0.346921     Validation accuracy:  0.6336
# Epoch 89, CIFAR-10 Batch 1:      Cost:  0.344332     Validation accuracy:  0.6322
# Epoch 89, CIFAR-10 Batch 2:      Cost:  0.402699     Validation accuracy:  0.634
# Epoch 89, CIFAR-10 Batch 3:      Cost:  0.251584     Validation accuracy:  0.6376
# Epoch 89, CIFAR-10 Batch 4:      Cost:  0.246583     Validation accuracy:  0.638
# Epoch 89, CIFAR-10 Batch 5:      Cost:  0.270611     Validation accuracy:  0.6418
# Epoch 90, CIFAR-10 Batch 1:      Cost:  0.325886     Validation accuracy:  0.6352
# Epoch 90, CIFAR-10 Batch 2:      Cost:  0.3367     Validation accuracy:  0.638
# Epoch 90, CIFAR-10 Batch 3:      Cost:  0.333391     Validation accuracy:  0.6322
# Epoch 90, CIFAR-10 Batch 4:      Cost:  0.269784     Validation accuracy:  0.641
# Epoch 90, CIFAR-10 Batch 5:      Cost:  0.227561     Validation accuracy:  0.6448
# Epoch 91, CIFAR-10 Batch 1:      Cost:  0.30264     Validation accuracy:  0.6308
# Epoch 91, CIFAR-10 Batch 2:      Cost:  0.379502     Validation accuracy:  0.6394
# Epoch 91, CIFAR-10 Batch 3:      Cost:  0.334995     Validation accuracy:  0.628
# Epoch 91, CIFAR-10 Batch 4:      Cost:  0.297267     Validation accuracy:  0.6412
# Epoch 91, CIFAR-10 Batch 5:      Cost:  0.293505     Validation accuracy:  0.6408
# Epoch 92, CIFAR-10 Batch 1:      Cost:  0.38758     Validation accuracy:  0.6346
# Epoch 92, CIFAR-10 Batch 2:      Cost:  0.361183     Validation accuracy:  0.6318
# Epoch 92, CIFAR-10 Batch 3:      Cost:  0.338049     Validation accuracy:  0.6322
# Epoch 92, CIFAR-10 Batch 4:      Cost:  0.302745     Validation accuracy:  0.6384
# Epoch 92, CIFAR-10 Batch 5:      Cost:  0.357035     Validation accuracy:  0.6372
# Epoch 93, CIFAR-10 Batch 1:      Cost:  0.292972     Validation accuracy:  0.6314
# Epoch 93, CIFAR-10 Batch 2:      Cost:  0.377736     Validation accuracy:  0.6324
# Epoch 93, CIFAR-10 Batch 3:      Cost:  0.295385     Validation accuracy:  0.6382
# Epoch 93, CIFAR-10 Batch 4:      Cost:  0.270604     Validation accuracy:  0.6364
# Epoch 93, CIFAR-10 Batch 5:      Cost:  0.271188     Validation accuracy:  0.6382
# Epoch 94, CIFAR-10 Batch 1:      Cost:  0.370749     Validation accuracy:  0.6378
# Epoch 94, CIFAR-10 Batch 2:      Cost:  0.326085     Validation accuracy:  0.634
# Epoch 94, CIFAR-10 Batch 3:      Cost:  0.315908     Validation accuracy:  0.6322
# Epoch 94, CIFAR-10 Batch 4:      Cost:  0.285566     Validation accuracy:  0.6282
# Epoch 94, CIFAR-10 Batch 5:      Cost:  0.317242     Validation accuracy:  0.639
# Epoch 95, CIFAR-10 Batch 1:      Cost:  0.310593     Validation accuracy:  0.631
# Epoch 95, CIFAR-10 Batch 2:      Cost:  0.364389     Validation accuracy:  0.6376
# Epoch 95, CIFAR-10 Batch 3:      Cost:  0.266787     Validation accuracy:  0.6412
# Epoch 95, CIFAR-10 Batch 4:      Cost:  0.264923     Validation accuracy:  0.6374
# Epoch 95, CIFAR-10 Batch 5:      Cost:  0.261563     Validation accuracy:  0.6392
# Epoch 96, CIFAR-10 Batch 1:      Cost:  0.281342     Validation accuracy:  0.6314
# Epoch 96, CIFAR-10 Batch 2:      Cost:  0.324327     Validation accuracy:  0.6398
# Epoch 96, CIFAR-10 Batch 3:      Cost:  0.323501     Validation accuracy:  0.6408
# Epoch 96, CIFAR-10 Batch 4:      Cost:  0.276423     Validation accuracy:  0.64
# Epoch 96, CIFAR-10 Batch 5:      Cost:  0.249176     Validation accuracy:  0.6396
# Epoch 97, CIFAR-10 Batch 1:      Cost:  0.290518     Validation accuracy:  0.642
# Epoch 97, CIFAR-10 Batch 2:      Cost:  0.310753     Validation accuracy:  0.6326
# Epoch 97, CIFAR-10 Batch 3:      Cost:  0.281706     Validation accuracy:  0.6406
# Epoch 97, CIFAR-10 Batch 4:      Cost:  0.312705     Validation accuracy:  0.6314
# Epoch 97, CIFAR-10 Batch 5:      Cost:  0.282183     Validation accuracy:  0.6448
# Epoch 98, CIFAR-10 Batch 1:      Cost:  0.298008     Validation accuracy:  0.6304
# Epoch 98, CIFAR-10 Batch 2:      Cost:  0.282385     Validation accuracy:  0.6356
# Epoch 98, CIFAR-10 Batch 3:      Cost:  0.266389     Validation accuracy:  0.6386
# Epoch 98, CIFAR-10 Batch 4:      Cost:  0.31777     Validation accuracy:  0.6332
# Epoch 98, CIFAR-10 Batch 5:      Cost:  0.251663     Validation accuracy:  0.6416
# Epoch 99, CIFAR-10 Batch 1:      Cost:  0.306156     Validation accuracy:  0.6374
# Epoch 99, CIFAR-10 Batch 2:      Cost:  0.300385     Validation accuracy:  0.6364
# Epoch 99, CIFAR-10 Batch 3:      Cost:  0.264518     Validation accuracy:  0.6412
# Epoch 99, CIFAR-10 Batch 4:      Cost:  0.274538     Validation accuracy:  0.6404
# Epoch 99, CIFAR-10 Batch 5:      Cost:  0.283502     Validation accuracy:  0.6398
# Epoch 100, CIFAR-10 Batch 1:      Cost:  0.269122     Validation accuracy:  0.6318
# Epoch 100, CIFAR-10 Batch 2:      Cost:  0.254867     Validation accuracy:  0.64
# Epoch 100, CIFAR-10 Batch 3:      Cost:  0.308457     Validation accuracy:  0.6346
# Epoch 100, CIFAR-10 Batch 4:      Cost:  0.25919     Validation accuracy:  0.639
# Epoch 100, CIFAR-10 Batch 5:      Cost:  0.21789     Validation accuracy:  0.6476

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6347426474094391

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
